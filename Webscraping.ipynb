# %% [markdown]
# <a href="https://colab.research.google.com/github/anaisaoviedo-upb/Webscraping-con-beautifulsoup/blob/main/Webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web scraping
#
# Extraer texto de páginas web de forma automática
#
# * Credenciales de la página web
# * Beautiful soup
#
#
#
# https://j2logo.com/python/web-scraping-con-python-guia-inicio-beautifulsoup/

# %%
#Cargamos librerías principales de python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Web Scraping
import requests
from bs4 import BeautifulSoup

# %%
#Se descarga el contenido de la página
url = 'https://www.elcolombiano.com'
r = requests.get(url)
html = r.content
html
# Out:
# b'     <!doctype html>  <html class="ltr" dir="ltr" lang="es-ES"> <head> <meta content="text/html; charset=UTF-8" http-equiv="content-type"> <title>El Colombiano | noticias de Medell\xc3\xadn, Antioquia, Colombia y el mundo.</title> <link rel="shortcut icon" href="https://estaticos.elcolombiano.com/base-portlet/webrsrc/ctxvar/7bacdb4bae8c4a41855e25ae67d07716.jpeg"> <style amp-custom> .mln_uppercase_mln\n\t\t{\n\t\t\ttext-transform:uppercase\n\t\t}\n\t\t\n\t\t.mln_small-caps_mln\n\t\t{\n\t\t\tfont-variant:small-caps\n\t\t}\n\t\t</style> <meta name="keywords" content="Noticias"> <meta name="keywords" content=" Medell\xc3\xadn"> <meta name="keywords" content=" Colombia"> <meta name="keywords" content=" multimedia"> <meta name="keywords" content=" \xc3\xbaltima hora"> <meta name="keywords" content=" actualidad"> <meta name="keywords" content=" internacional"> <meta name="keywords" content=" entretenimiento"> <meta name="keywords" content=" cultura"> <meta name="robots" content="index, fo
# ...

# %%
#Se crea un objeto con el parser html para identificar etiquetas y texto
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
#  <!DOCTYPE html>
#  <html class="ltr" dir="ltr" lang="es-ES"> <head> <meta content="text/html; charset=utf-8" http-equiv="content-type"/> <title>El Colombiano | noticias de Medellín, Antioquia, Colombia y el mundo.</title> <link href="https://estaticos.elcolombiano.com/base-portlet/webrsrc/ctxvar/7bacdb4bae8c4a41855e25ae67d07716.jpeg" rel="shortcut icon"/> <style amp-custom=""> .mln_uppercase_mln
# 		{
# 			text-transform:uppercase
# 		}
#
# 		.mln_small-caps_mln
# 		{
# 			font-variant:small-caps
# 		}
# ...

# %%
#Se obtiene el texto (incluye caracteres especiales)
texto = soup.get_text()
texto
# Out:
# '     El Colombiano | noticias de Medellín, Antioquia, Colombia y el mundo.                                                                                                                                        x               personMi Colombiano   graphic_eqPódcast   play_arrowVideos   photo_cameraReportajes gráficos   account_circleSuscríbete                               pico y placa \n            Pico y Placa Medellín \n                 Pico y Placa Medellín       viernes 0 y 6\xa0 0 y 6     pico y placa \n            Pico y Placa Medellín \n              Pico y Placa Medellín       jueves 1 y 7\xa0 1 y 7     pico y placa \n            Pico y Placa Medellín \n              Pico y Placa Medellín       miercoles 5 y 9\xa0 5 y 9     pico y placa \n            Pico y Placa Medellín \n              Pico y Placa Medellín       martes 2 y 8 \xa0 2 y 8     pico y placa \n            Pico y Placa Medellín \n              Pico y Placa Medellín     domingo  no  no     pico y placa \n       
# ...

# %%
# Se busca el contenido con una etiqueta específica
contenido= soup.find_all(class_='priority-content')
contenido
# Out:
# [<span class="priority-content" mlnid="idcon=47716340;order=2.0">¿Qué pasó en París? Pistas de la acusación del excanciller Leyva a Petro sobre supuesto consumo de drogas</span>,
#  <span class="priority-content" mlnid="idcon=47716340;order=2.0">¿Qué pasó en París? Pistas de la acusación del excanciller Leyva a Petro sobre supuesto consumo de drogas</span>,
#  <span class="priority-content" mlnid="idcon=47709289;order=3.0">“Fue en París donde pude confirmar que usted tenía el problema de la drogadicción”: la dura carta de Álvaro Leyva a Gustavo Petro</span>,
#  <span class="priority-content" mlnid="idcon=47717163;order=2.0">Enfermero personal del papa Francisco asegura que: “No sufrió, todo sucedió rápidamente”</span>,
#  <span class="priority-content" mlnid="idcon=47717163;order=2.0">Enfermero personal del papa Francisco asegura que: “No sufrió, todo sucedió rápidamente”</span>,
# ...

# %%
# El resultado se convierte a un dataframe
matriz=[]
data = pd.DataFrame()

for row in contenido:
  matriz.append(row.text.strip())

data['noticias'] =matriz
data
# Out:
#                                               noticias
# 0    ¿Qué pasó en París? Pistas de la acusación del...
# 1    ¿Qué pasó en París? Pistas de la acusación del...
# 2    “Fue en París donde pude confirmar que usted t...
# 3    Enfermero personal del papa Francisco asegura ...
# 4    Enfermero personal del papa Francisco asegura ...
# ..                                                 ...
# 195  Felipe Bayón, expresidente de Ecopetrol, será ...
# 196  Dólar se da un leve respiro y abre a la baja e...
# 197  Dólar se da un leve respiro y abre a la baja e...
# 198  Banco Mundial también rebajó la perspectiva de...
# 199  Banco Mundial también rebajó la perspectiva de...
#
# [200 rows x 1 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   noticias  200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# # Ahora puedes analizar las noticias de forma tradicional con Bag og words o con un neural embedding...o quizás puedas usar un LLM
